# %%
from paddleocr import LayoutDetection

model = LayoutDetection(model_name="PP-DocLayout-L",model_dir='/home/christopher.paulraj@zucisystems.com/Documents/python/models/PP-DocLayout-L/official_models/PP-DocLayout-L')
output = model.predict("/home/christopher.paulraj@zucisystems.com/Downloads/SYNT_166529664_c1_page-0001.jpg", batch_size=1)
for res in output:
    res.print()
    res.save_to_img(save_path="/home/christopher.paulraj@zucisystems.com/Documents/python/output")
    res.save_to_json(save_path="/home/christopher.paulraj@zucisystems.com/Documents/python/output/res.json")
# Out:
# {'res': {'input_path': '/home/christopher.paulraj@zucisystems.com/Downloads/SYNT_166529664_c1_page-0001.jpg', 'page_index': None, 'boxes': [{'cls_id': 2, 'label': 'text', 'score': 0.8693634271621704, 'coordinate': [np.float32(151.62093), np.float32(452.1399), np.float32(1131.1371), np.float32(490.23465)]}, {'cls_id': 13, 'label': 'header', 'score': 0.8587374687194824, 'coordinate': [np.float32(77.47354), np.float32(27.922514), np.float32(446.63394), np.float32(48.00156)]}, {'cls_id': 8, 'label': 'table', 'score': 0.841286838054657, 'coordinate': [np.float32(105.99022), np.float32(528.70996), np.float32(1126.7162), np.float32(1007.5885)]}, {'cls_id': 2, 'label': 'text', 'score': 0.7651127576828003, 'coordinate': [np.float32(152.95197), np.float32(491.19345), np.float32(1114.4691), np.float32(525.79034)]}, {'cls_id': 2, 'label': 'text', 'score': 0.7584556341171265, 'coordinate': [np.float32(166.16861), np.float32(348.3337), np.float32(1073.7476), np.float32(412.60666)]}, {'cls_id': 20,
# ...
